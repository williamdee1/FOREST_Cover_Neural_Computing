# %%
import numpy as np
import pandas as pd
import time

from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from imblearn.under_sampling import RandomUnderSampler, TomekLinks
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV 
from sklearn.metrics import make_scorer, accuracy_score, f1_score
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Loading Datasets:

# %%
# Training Set:
X_train = pd.read_csv('Data/X_train.csv')
y_train = pd.read_csv('Data/y_train.csv', header=None)

# %%
print("X_train Length: {:,}".format(len(X_train)))
print("y_train Length: {:,}".format(len(y_train)))
# Out:
# X_train Length: 464,809
# y_train Length: 464,809

# %%
# Definining Scaler:
scaler = MinMaxScaler()

# Fitting scaler on X_train (which also converts to an array):
X_train = scaler.fit_transform(X_train)

# %%
# Converting y_train into an array:
y_train = np.array(y_train[0])

# %%
seed = 42

# %% [markdown]
# # Define Params to Search:

# %%
# RANDOM SEARCH FOR COMBINATIONS OF PARAMETERS
rand_list = {"C": stats.expon(scale=50),
             "gamma": stats.uniform(0.1, 0.99)}

# %% [markdown]
# # Sampling Strategies:

# %%
# Sampling strategies to loop through:
tomek = [TomekLinks(sampling_strategy=[1,2]), 'None']

# Undersampling the two majority classes - Types 1 & 2:
unders = [(0.85, 0.85),                   # 15 % undersampling of majority classes
          (0.75, 0.75),                   # 25 %
          (0.60, 0.60),                   # 40 %
          (0.40, 0.40),                   # 60 %
          (0.20, 0.20),                   # 80 %
          (0.55, 0.40)  ]                 # Imbalanced undersampling

# Oversampling the 5 minority classes - Types 3, 4, 5, 6 & 7:
overs = [(1.2, 1.2, 1.2, 1.2, 1.2),       # SMOTE - 20% oversampling
         (1.5, 1.5, 1.5, 1.5, 1.5),       # 50% oversampling
         (2.0, 2.0, 2.0, 2.0, 2.0),       # 100% oversampling
         (4.0, 4.0, 4.0, 4.0, 4.0),       # 300% oversampling
         (6.0, 6.0, 6.0, 6.0, 6.0),       # 500% oversampling
         (2.0, 10.0, 10.0, 5.0, 4.0),     # Imbalanced oversampling
         (0),                             # Equalizing minority classes with majority
         
         (1.2, 1.2, 1.2, 1.2, 1.2),       # Borderline SMOTE - 20% oversampling
         (1.5, 1.5, 1.5, 1.5, 1.5),       # 50% oversampling
         (2.0, 2.0, 2.0, 2.0, 2.0),       # 100% oversampling
         (4.0, 4.0, 4.0, 4.0, 4.0),       # 300% oversampling
         (6.0, 6.0, 6.0, 6.0, 6.0),       # 500% oversampling
         (2.0, 10.0, 10.0, 5.0, 4.0),     # Imbalanced oversampling
         (0),  ]                          # Equalizing minority classes with majority

# %% [markdown]
# # Gridsearch:

# %%
# Function to return index
def get_count(array, cov_type, percent):
        # Count the number of a specific cover type in the current split array to define sampling bounds:
        count = round(array.tolist().count(cov_type)*percent)
        return count

# %%
######## RANDOM SEARCH ########
  
iters = 10
eval_metric = make_scorer(accuracy_score)

test_results = np.zeros(((iters*len(tomek)*len(unders)*len(overs)), 7))


loop_counter = 0

print("TOTAL LOOPS = ", (len(tomek)*len(unders)*len(overs)))


for t in range(len(tomek)):

    for u in range(len(unders)):

        for o in range(len(overs)):

            # Defining the model, looping through the list of available kernels:
            svm_model = svm.SVC(kernel='rbf')


            # Using train-test split to split out a random, stratified 10% portion of the training data to grid search:
            X_gs, X_leave, y_gs, y_leave = train_test_split(X_train, y_train, 
                                                    test_size = 0.9,     # Inverse of the size of the data to search
                                                    stratify = y_train,  # Keeping same proportion of target classes
                                                   random_state = seed)  


             ###### APPLYING SAMPLING STRATEGY ######
            # Appling sampling strategies to X_train/y_train after splitting for Cross-val

            # Only applying Tomek Links on half the loops (t = 0 or 1):
            if t == 0:
                resample = tomek[t]
                X_gs, y_gs = resample.fit_resample(X_gs, y_gs)

            # Undersampling applied on majority classes according to methods above:
            under_strategy = {1:get_count(y_gs, 1, unders[u][0]),
                              2:get_count(y_gs, 2, unders[u][1])}

            undersample = RandomUnderSampler(sampling_strategy = under_strategy)
            X_gs, y_gs = undersample.fit_resample(X_gs, y_gs)

            # Oversampling applied on minority classes according to methods above:
            if o == 6:
                oversample = SMOTE()
            elif o == 13:
                oversample = BorderlineSMOTE()
            elif o < 6:
                over_strategy = {3:get_count(y_gs, 3, overs[o][0]),
                                 4:get_count(y_gs, 4, overs[o][1]),
                                 5:get_count(y_gs, 5, overs[o][2]),
                                 6:get_count(y_gs, 6, overs[o][3]),
                                 7:get_count(y_gs, 7, overs[o][4]),
                                }
                oversample = SMOTE(sampling_strategy = over_strategy)
            else:
                over_strategy = {3:get_count(y_gs, 3, overs[o][0]),
                                 4:get_count(y_gs, 4, overs[o][1]),
                                 5:get_count(y_gs, 5, overs[o][2]),
                                 6:get_count(y_gs, 6, overs[o][3]),
                                 7:get_count(y_gs, 7, overs[o][4]),
                                }
                oversample = BorderlineSMOTE(sampling_strategy = over_strategy)

            X_gs, y_gs = oversample.fit_resample(X_gs, y_gs)


            print("Starting Loop {:.0f}".format(loop_counter))
            loop_counter += 1

            start = time.time()
            # Setting the random search parameters:
            rand_search = RandomizedSearchCV(svm_model, 
                                             param_distributions = rand_list, # Sets to params specified above 
                                             n_iter = iters,                  # No. sampled parameter settings, 10 = default
                                             n_jobs = -1,                     # Set to -1 to use all available CPU processors
                                             cv = 4,                          # Cross-validation folds
                                             scoring = eval_metric)           # Scoring metric chosen

            # Fitting the random search to the sampled data:
            rand_search.fit(X_gs, y_gs)

            # CV Results
            cv_res = rand_search.cv_results_

            # Appending Results:
            idx = o+(u*len(overs))+(t*(len(unders)*len(overs)))
            test_results[idx*iters: (idx+1)*iters, 0] = cv_res['mean_test_score']
            test_results[idx*iters: (idx+1)*iters, 1] = cv_res['mean_fit_time']
            test_results[idx*iters: (idx+1)*iters, 2] = [d['C'] for d in rand_search.cv_results_['params']]
            test_results[idx*iters: (idx+1)*iters, 3] = [d['gamma'] for d in rand_search.cv_results_['params']]
            test_results[idx*iters: (idx+1)*iters, 4] = t
            test_results[idx*iters: (idx+1)*iters, 5] = u
            test_results[idx*iters: (idx+1)*iters, 6] = o


            end = time.time()
            time_taken = end - start

            print("Time taken for Grid Search loop: ", time_taken)
# Out:
# TOTAL LOOPS =  168
# Starting Loop 0
# Time taken for Grid Search loop:  315.9313654899597
# Starting Loop 1
# Time taken for Grid Search loop:  369.21482014656067
# Starting Loop 2
# Time taken for Grid Search loop:  345.05234360694885
# Starting Loop 3
# Time taken for Grid Search loop:  543.0894181728363
# Starting Loop 4
# Time taken for Grid Search loop:  639.5210440158844
# Starting Loop 5
# Time taken for Grid Search loop:  522.3280820846558
# Starting Loop 6
# Time taken for Grid Search loop:  1401.7313549518585
# Starting Loop 7
# Time taken for Grid Search loop:  305.7166426181793
# Starting Loop 8
# Time taken for Grid Search loop:  344.96580624580383
# Starting Loop 9
# Time taken for Grid Search loop:  388.34884762763977
# Starting Loop 10
# Time taken for Grid Search loop:  536.6972608566284
# Starting Loop 11
# Time taken for Grid Search loop:  702.2991688251495
# Starting Loop 12
# Time taken for Grid Search loop:  558.3931982517242
# Starting Loop 13
# Time taken for Grid Search loop:  1765.0403351783752
# Starting Loop 14
# Time taken for Grid Search loop:  246.69106912612915
# Starting Loop 15
# Time taken for Grid Search loop:  250.95901536941528
# Starting Loop 16
# Time taken for Grid Search loop:  286.8787817955017
# Starting Loop 17
# Time taken for Grid Search loop:  391.8672604560852
# Starting Loop 18
# Time taken for Grid Search loop:  546.0464916229248
# Starting Loop 19
# Time taken for Grid Search loop:  406.07962703704834
# Starting Loop 20
# Time taken for Grid Search loop:  1108.7775423526764
# Starting Loop 21
# Time taken for Grid Search loop:  271.0995090007782
# Starting Loop 22
# Time taken for Grid Search loop:  289.26083517074585
# Starting Loop 23
# Time taken for Grid Search loop:  283.3596305847168
# Starting Loop 24
# Time taken for Grid Search loop:  433.0701525211334
# Starting Loop 25
# Time taken for Grid Search loop:  635.460203409195
# Starting Loop 26
# Time taken for Grid Search loop:  444.9926247596741
# Starting Loop 27
# Time taken for Grid Search loop:  1335.391666650772
# Starting Loop 28
# Time taken for Grid Search loop:  161.12596440315247
# Starting Loop 29
# Time taken for Grid Search loop:  176.67671704292297
# Starting Loop 30
# Time taken for Grid Search loop:  191.23693752288818
# Starting Loop 31
# Time taken for Grid Search loop:  287.8052990436554
# Starting Loop 32
# Time taken for Grid Search loop:  423.16376066207886
# Starting Loop 33
# Time taken for Grid Search loop:  319.7027654647827
# Starting Loop 34
# Time taken for Grid Search loop:  697.7072849273682
# Starting Loop 35
# Time taken for Grid Search loop:  153.0046615600586
# Starting Loop 36
# Time taken for Grid Search loop:  184.9817910194397
# Starting Loop 37
# Time taken for Grid Search loop:  202.07040238380432
# Starting Loop 38
# Time taken for Grid Search loop:  350.7222890853882
# Starting Loop 39
# Time taken for Grid Search loop:  484.89628624916077
# Starting Loop 40
# Time taken for Grid Search loop:  345.0362513065338
# Starting Loop 41
# Time taken for Grid Search loop:  862.8747625350952
# Starting Loop 42
# Time taken for Grid Search loop:  72.15826773643494
# Starting Loop 43
# Time taken for Grid Search loop:  80.99498653411865
# Starting Loop 44
# Time taken for Grid Search loop:  100.27870345115662
# Starting Loop 45
# Time taken for Grid Search loop:  181.0225064754486
# Starting Loop 46
# Time taken for Grid Search loop:  302.9021632671356
# Starting Loop 47
# Time taken for Grid Search loop:  192.29630970954895
# Starting Loop 48
# Time taken for Grid Search loop:  352.4184148311615
# Starting Loop 49
# Time taken for Grid Search loop:  73.67650866508484
# Starting Loop 50
# Time taken for Grid Search loop:  90.14341998100281
# Starting Loop 51
# Time taken for Grid Search loop:  106.65583777427673
# Starting Loop 52
# Time taken for Grid Search loop:  223.23991632461548
# Starting Loop 53
# Time taken for Grid Search loop:  390.22197246551514
# Starting Loop 54
# Time taken for Grid Search loop:  212.2993505001068
# Starting Loop 55
# Time taken for Grid Search loop:  354.54660844802856
# Starting Loop 56
# Time taken for Grid Search loop:  21.527724504470825
# Starting Loop 57
# Time taken for Grid Search loop:  25.5310697555542
# Starting Loop 58
# Time taken for Grid Search loop:  35.20983076095581
# Starting Loop 59
# Time taken for Grid Search loop:  100.06023669242859
# Starting Loop 60
# Time taken for Grid Search loop:  222.459796667099
# Starting Loop 61
# Time taken for Grid Search loop:  95.0494077205658
# Starting Loop 62
# Time taken for Grid Search loop:  61.71760964393616
# Starting Loop 63
# Time taken for Grid Search loop:  22.057384490966797
# Starting Loop 64
# Time taken for Grid Search loop:  29.990286827087402
# Starting Loop 65
# Time taken for Grid Search loop:  41.24340057373047
# Starting Loop 66
# Time taken for Grid Search loop:  133.72594380378723
# Starting Loop 67
# Time taken for Grid Search loop:  260.58878231048584
# Starting Loop 68
# Time taken for Grid Search loop:  118.40462636947632
# Starting Loop 69
# Time taken for Grid Search loop:  78.4571361541748
# Starting Loop 70
# Time taken for Grid Search loop:  96.3900215625763
# Starting Loop 71
# Time taken for Grid Search loop:  106.38811779022217
# Starting Loop 72
# Time taken for Grid Search loop:  125.42863345146179
# Starting Loop 73
# Time taken for Grid Search loop:  225.44886827468872
# Starting Loop 74
# Time taken for Grid Search loop:  350.2170419692993
# Starting Loop 75
# Time taken for Grid Search loop:  206.41335725784302
# Starting Loop 76
# Time taken for Grid Search loop:  327.5472536087036
# Starting Loop 77
# Time taken for Grid Search loop:  96.31232738494873
# Starting Loop 78
# Time taken for Grid Search loop:  109.76209664344788
# Starting Loop 79
# Time taken for Grid Search loop:  131.9711470603943
# Starting Loop 80
# Time taken for Grid Search loop:  247.8841323852539
# Starting Loop 81
# Time taken for Grid Search loop:  391.27332186698914
# Starting Loop 82
# Time taken for Grid Search loop:  246.99714303016663
# Starting Loop 83
# Time taken for Grid Search loop:  351.7073583602905
# Starting Loop 84
# Time taken for Grid Search loop:  375.45985984802246
# Starting Loop 85
# Time taken for Grid Search loop:  422.5496311187744
# Starting Loop 86
# Time taken for Grid Search loop:  416.04899168014526
# Starting Loop 87
# Time taken for Grid Search loop:  533.8827066421509
# Starting Loop 88
# Time taken for Grid Search loop:  743.9183714389801
# Starting Loop 89
# Time taken for Grid Search loop:  585.7144873142242
# Starting Loop 90
# Time taken for Grid Search loop:  1722.1233224868774
# Starting Loop 91
# Time taken for Grid Search loop:  419.2162823677063
# Starting Loop 92
# Time taken for Grid Search loop:  431.2551472187042
# Starting Loop 93
# Time taken for Grid Search loop:  419.6436860561371
# Starting Loop 94
# Time taken for Grid Search loop:  577.607616186142
# Starting Loop 95
# Time taken for Grid Search loop:  833.4560151100159
# Starting Loop 96
# Time taken for Grid Search loop:  588.2705821990967
# Starting Loop 97
# Time taken for Grid Search loop:  1822.9268667697906
# Starting Loop 98
# Time taken for Grid Search loop:  285.2035005092621
# Starting Loop 99
# Time taken for Grid Search loop:  282.78411960601807
# Starting Loop 100
# Time taken for Grid Search loop:  317.49224972724915
# Starting Loop 101
# Time taken for Grid Search loop:  519.3029372692108
# Starting Loop 102
# Time taken for Grid Search loop:  621.6733691692352
# Starting Loop 103
# Time taken for Grid Search loop:  476.5854215621948
# Starting Loop 104
# Time taken for Grid Search loop:  1165.5356328487396
# Starting Loop 105
# Time taken for Grid Search loop:  293.5025587081909
# Starting Loop 106
# Time taken for Grid Search loop:  303.61419129371643
# Starting Loop 107
# Time taken for Grid Search loop:  335.4132630825043
# Starting Loop 108
# Time taken for Grid Search loop:  478.63637804985046
# Starting Loop 109
# Time taken for Grid Search loop:  667.8849339485168
# Starting Loop 110
# Time taken for Grid Search loop:  466.66986107826233
# Starting Loop 111
# Time taken for Grid Search loop:  1441.937315940857
# Starting Loop 112
# Time taken for Grid Search loop:  170.81419229507446
# Starting Loop 113
# Time taken for Grid Search loop:  207.78799057006836
# Starting Loop 114
# Time taken for Grid Search loop:  217.16451144218445
# Starting Loop 115
# Time taken for Grid Search loop:  346.67354679107666
# Starting Loop 116
# Time taken for Grid Search loop:  466.29612040519714
# Starting Loop 117
# Time taken for Grid Search loop:  342.32345175743103
# Starting Loop 118
# Time taken for Grid Search loop:  767.5072240829468
# Starting Loop 119
# Time taken for Grid Search loop:  193.00302362442017
# Starting Loop 120
# Time taken for Grid Search loop:  202.04849767684937
# Starting Loop 121
# Time taken for Grid Search loop:  221.36763215065002
# Starting Loop 122
# Time taken for Grid Search loop:  361.6896622180939
# Starting Loop 123
# Time taken for Grid Search loop:  525.229161977768
# Starting Loop 124
# Time taken for Grid Search loop:  364.89438700675964
# Starting Loop 125
# Time taken for Grid Search loop:  993.9411137104034
# Starting Loop 126
# Time taken for Grid Search loop:  85.0226092338562
# Starting Loop 127
# Time taken for Grid Search loop:  92.39948511123657
# Starting Loop 128
# Time taken for Grid Search loop:  104.89396095275879
# Starting Loop 129
# Time taken for Grid Search loop:  198.73712491989136
# Starting Loop 130
# Time taken for Grid Search loop:  372.6553318500519
# Starting Loop 131
# Time taken for Grid Search loop:  193.83226084709167
# Starting Loop 132
# Time taken for Grid Search loop:  326.16169714927673
# Starting Loop 133
# Time taken for Grid Search loop:  82.37936687469482
# Starting Loop 134
# Time taken for Grid Search loop:  95.47585391998291
# Starting Loop 135
# Time taken for Grid Search loop:  115.23886752128601
# Starting Loop 136
# Time taken for Grid Search loop:  242.39005613327026
# Starting Loop 137
# Time taken for Grid Search loop:  356.60506558418274
# Starting Loop 138
# Time taken for Grid Search loop:  219.35120296478271
# Starting Loop 139
# Time taken for Grid Search loop:  400.3058876991272
# Starting Loop 140
# Time taken for Grid Search loop:  22.14239478111267
# Starting Loop 141
# Time taken for Grid Search loop:  27.64403533935547
# Starting Loop 142
# Time taken for Grid Search loop:  38.66040802001953
# Starting Loop 143
# Time taken for Grid Search loop:  110.16171765327454
# Starting Loop 144
# Time taken for Grid Search loop:  202.44787049293518
# Starting Loop 145
# Time taken for Grid Search loop:  94.17353463172913
# Starting Loop 146
# Time taken for Grid Search loop:  68.30764484405518
# Starting Loop 147
# Time taken for Grid Search loop:  24.005505800247192
# Starting Loop 148
# Time taken for Grid Search loop:  29.609618186950684
# Starting Loop 149
# Time taken for Grid Search loop:  43.085031032562256
# Starting Loop 150
# Time taken for Grid Search loop:  137.902930021286
# Starting Loop 151
# Time taken for Grid Search loop:  267.80093002319336
# Starting Loop 152
# Time taken for Grid Search loop:  120.13870120048523
# Starting Loop 153
# Time taken for Grid Search loop:  82.25502395629883
# Starting Loop 154
# Time taken for Grid Search loop:  109.11471009254456
# Starting Loop 155
# Time taken for Grid Search loop:  124.8661458492279
# Starting Loop 156
# Time taken for Grid Search loop:  133.97601532936096
# Starting Loop 157
# Time taken for Grid Search loop:  237.37768030166626
# Starting Loop 158
# Time taken for Grid Search loop:  359.40653824806213
# Starting Loop 159
# Time taken for Grid Search loop:  245.5163049697876
# Starting Loop 160
# Time taken for Grid Search loop:  355.4308943748474
# Starting Loop 161
# Time taken for Grid Search loop:  115.10184717178345
# Starting Loop 162
# Time taken for Grid Search loop:  121.3401746749878
# Starting Loop 163
# Time taken for Grid Search loop:  146.86815404891968
# Starting Loop 164
# Time taken for Grid Search loop:  266.7583794593811
# Starting Loop 165
# Time taken for Grid Search loop:  416.2599940299988
# Starting Loop 166
# Time taken for Grid Search loop:  269.0155825614929
# Starting Loop 167
# Time taken for Grid Search loop:  415.17683815956116

# %% [markdown]
# # Mapping Results to Dataframe and Saving as Csv:

# %%
test_res_df_samp = pd.DataFrame(test_results, columns= ['mean_test_score', "mean_fit_time", 'C', 'Gamma',
                                                       'tomek', 'under_strat', 'over_strat'])

# %%
tomek_map = {0: 'TL', 1: 'No TL'}
under_map = {0: '-15%', 1: '-25%', 2: '-40%', 3: '-60%', 4: '-80%', 5: 'Imbal'}
over_map = {0: '+20% S', 1: '+50% S', 2: '+100% S', 3: '+300% S', 4: '+500% S', 5: 'Imbal S', 6: 'SMOTE',
            7: '+20% BS', 8: '+50% BS', 9: '+100% BS', 10: '+300% BS', 11: '+500% BS', 12: 'Imbal BS', 13: 'BoSMOTE'}

# %%
test_res_df_samp['tomek'] = test_res_df_samp['tomek'].map(tomek_map)
test_res_df_samp['under_strat'] = test_res_df_samp['under_strat'].map(under_map)
test_res_df_samp['over_strat'] = test_res_df_samp['over_strat'].map(over_map)

# %%
test_res_df_samp.sort_values(by = 'mean_test_score', ascending=False)
# Out:
#       mean_test_score  mean_fit_time           C     Gamma  tomek under_strat  \
# 62           0.926540     304.765204  142.452992  1.005504     TL        -15%
# 901          0.920481     388.256793  268.301587  0.782780  No TL        -15%
# 347          0.915996     139.882393   92.085811  1.079928     TL        -40%
# 202          0.914451     190.281967  112.736727  0.754321     TL        -25%
# 346          0.913354     128.682077   88.801957  1.003014     TL        -40%
# 69           0.913298     161.436364   73.781407  0.849985     TL        -15%
# 65           0.912656     258.278818   70.626966  0.849978     TL        -15%
# 1048         0.910964     136.228243   64.892039  1.056299  No TL        -25%
# 762          0.910460      62.134983  148.652672  1.089462     TL       Imbal
# 488          0.909125      46.025634  130.499545  0.995317     TL        -60%
# 201          0.907434     166.763642   47.031950  0.903455     TL        -25%
# 1606         0.903337      66.281717  148.815974  0.907810  No TL       Imbal
# 344          0.903256     124.753549   49.488979  0.940614     TL        -40%
# 206          0.903172     205.573501   95.511753  0.574344     TL        -25%
# 1049         0.902400     113.950472   40.435645  0.986870  No TL        -25%
# 1184         0.901593     154.108905  125.247264  0.662483  No TL        -40%
# 1327         0.900980      59.016432  116.600567  0.885533  No TL        -60%
# 461          0.900154      62.348689  147.617383  0.898862     TL        -60%
# 1041         0.899660     213.631095   52.088397  0.811779  No TL        -25%
# 607          0.899108      44.558544   78.500877  0.801641     TL        -80%
# 66           0.898841     233.617458   36.739731  0.756214     TL        -15%
# 1329         0.898333      28.358345   72.556070  1.003017  No TL        -60%
# 1181         0.897748     139.082086   43.377469  0.937083  No TL        -40%
# 1605         0.897727      62.904284  102.921682  0.857545  No TL       Imbal
# 1047         0.897374     202.020208   26.311527  1.051433  No TL        -25%
# 1185         0.896350     134.673302   42.092599  0.913605  No TL        -40%
# 1045         0.895820     211.283510   41.650241  0.797980  No TL        -25%
# 1603         0.895367      64.375712   70.994931  0.951159  No TL       Imbal
# 595          0.894883      20.045877  108.723029  1.044599     TL        -80%
# 1325         0.894409      54.902537   71.253944  0.910971  No TL        -60%
# ...               ...            ...         ...       ...    ...         ...
# 1350         0.690667      21.113899    4.793060  0.240779  No TL        -60%
# 1308         0.689847      51.675465    0.255860  0.241986  No TL        -60%
# 384          0.689321      82.819471    1.315150  0.334215     TL        -40%
# 1628         0.688960      16.052502   11.550837  0.102667  No TL       Imbal
# 787          0.688264      18.432926    3.075444  0.207557     TL       Imbal
# 374          0.686352      46.119817    2.933415  0.178131     TL        -40%
# 646          0.685698       3.962700    9.584959  0.244329     TL        -80%
# 104          0.685214     139.257446    2.789697  0.133458     TL        -15%
# 808          0.683181      31.549574    0.731040  0.578996     TL       Imbal
# 377          0.680943      42.173956    3.269286  0.139232     TL        -40%
# 426          0.679492      15.448896    0.265041  0.272354     TL        -60%
# 1627         0.675750      25.394320    0.747484  0.464746  No TL       Imbal
# 332          0.671786     117.628290    0.114049  0.734340     TL        -40%
# 809          0.670895      28.633394    1.124442  0.249447     TL       Imbal
# 487          0.669325     127.035287    0.092220  0.281916     TL        -60%
# 1229         0.668046      45.967122    2.416887  0.134511  No TL        -40%
# 1634         0.663750      29.455372    0.730564  0.512064  No TL       Imbal
# 782          0.663732      22.846039    0.880527  0.198352     TL       Imbal
# 640          0.654352       4.235750    6.429696  0.146665     TL        -80%
# 1418         0.649293       3.886686    0.555154  0.158715  No TL        -80%
# 533          0.647763     129.020972    0.359494  0.187892     TL        -60%
# 1424         0.644968       6.573662    0.346158  0.174475  No TL        -80%
# 1269         0.644678       9.660539    0.189559  0.199029  No TL        -60%
# 771          0.630217      34.843828    0.037132  1.048661     TL       Imbal
# 1534         0.629889      19.977866    0.228558  0.402475  No TL        -80%
# 644          0.628268       4.535967    1.601815  0.236967     TL        -80%
# 1369         0.626625      27.445515    0.313391  0.238738  No TL        -60%
# 647          0.624853       4.699665    0.819503  0.375660     TL        -80%
# 404          0.623065     130.585913    0.790101  0.103831     TL        -40%
# 655          0.571573       9.224131    0.155038  0.264660     TL        -80%
#
#      over_strat
# 62        SMOTE
# 901       SMOTE
# 347       SMOTE
# 202       SMOTE
# 346       SMOTE
# 69        SMOTE
# 65        SMOTE
# 1048      SMOTE
# 762       SMOTE
# 488       SMOTE
# 201       SMOTE
# 1606      SMOTE
# 344       SMOTE
# 206       SMOTE
# 1049      SMOTE
# 1184      SMOTE
# 1327      SMOTE
# 461     +500% S
# 1041      SMOTE
# 607     +500% S
# 66        SMOTE
# 1329      SMOTE
# 1181      SMOTE
# 1605      SMOTE
# 1047      SMOTE
# 1185      SMOTE
# 1045      SMOTE
# 1603      SMOTE
# 595     +300% S
# 1325      SMOTE
# ...         ...
# 1350   +100% BS
# 1308    +500% S
# 384    +300% BS
# 1628    +50% BS
# 787     +50% BS
# 374    +100% BS
# 646     +50% BS
# 104    +300% BS
# 808    +300% BS
# 377    +100% BS
# 426      +20% S
# 1627    +50% BS
# 332     Imbal S
# 809    +300% BS
# 487       SMOTE
# 1229   +300% BS
# 1634   +100% BS
# 782     +50% BS
# 640     +50% BS
# 1418     +50% S
# 533    +500% BS
# 1424    +100% S
# 1269     +20% S
# 771     +20% BS
# 1534    BoSMOTE
# 644     +50% BS
# 1369   +300% BS
# 647     +50% BS
# 404    Imbal BS
# 655    +100% BS
#
# [1680 rows x 7 columns]

# %%
test_res_df_samp.to_csv('Data/sampling_SVM_gridsearch.csv')
